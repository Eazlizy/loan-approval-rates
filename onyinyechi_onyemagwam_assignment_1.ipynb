# %% [markdown]
# <a href="https://colab.research.google.com/github/Eazlizy/loan-approval-rates/blob/main/onyinyechi_onyemagwam_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##loan approval rates

# %%
import pandas as pd

# %%
url='https://raw.githubusercontent.com/Eazlizy/loan-approval-rates/main/loan%20approval%20rates.csv'
df = pd.read_csv(url)

# %%
Loan.head(100)
# Out:
#     Applicant number Total Debt ($) Annual Income ($) DTI Ratio(%)  \
# 0                  1    2,699,591          11,855,260          23%
# 1                  2   10,533,816          10,023,835         105%
# 2                  3   14,751,324          15,005,604          98%
# 3                  4    4,388,501           4,294,936         102%
# 4                  5    6,139,463          11,554,404          53%
# ..               ...            ...               ...          ...
# 95                96      9,366,383      33,602,376            28%
# 96                97      1,357,195      13,090,630            10%
# 97                98        883,928      38,432,823             2%
# 98                99     54,035,747     198,000,317            27%
# 99               100    132,308,185     195,330,621            68%
#
#    Approval status
# 0         Approved
# 1         Declined
# 2         Declined
# 3         Declined
# 4         Declined
# ..             ...
# ...

# %%
Loan = pd.read_csv(url)

# %%
Loan.isnull()
# Out:
#     Applicant number  Total Debt ($)  Annual Income ($)  DTI Ratio(%)  \
# 0              False           False              False         False
# 1              False           False              False         False
# 2              False           False              False         False
# 3              False           False              False         False
# 4              False           False              False         False
# ..               ...             ...                ...           ...
# 95             False           False              False         False
# 96             False           False              False         False
# 97             False           False              False         False
# 98             False           False              False         False
# 99             False           False              False         False
#
#     Approval status
# 0             False
# 1             False
# 2             False
# 3             False
# ...

# %%
Loan.describe()
# Out:
#        Applicant number
# count        100.000000
# mean          50.500000
# std           29.011492
# min            1.000000
# 25%           25.750000
# 50%           50.500000
# 75%           75.250000
# max          100.000000

# %%
Loan.dtypes
# Out:
# Applicant number      int64
# Total Debt ($)       object
# Annual Income ($)    object
# DTI Ratio(%)         object
# Approval status      object
# dtype: object

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Eazlizy/loan-approval-rates/main/loan%20approval%20rates.csv'
reinforce = pd.read_csv(url)
reinforce.sum()
# Out:
# Applicant number                                                  5050
# Total Debt ($)       2,699,591  10,533,816  14,751,324  4,388,501  ...
# Annual Income ($)    11,855,26010,023,83515,005,6044,294,93611,554,...
# DTI Ratio(%)         23%105%98%102%53%179%7%73%192%209%100%100%115%...
# Approval status      ApprovedDeclinedDeclinedDeclinedDeclinedDeclin...
# dtype: object

# %%
df['DTI Ratio(%)'] = df['DTI Ratio(%)'].str.rstrip('%').astype(float)
print(df.head())
print(df.describe())
# Out:
#    Applicant number Total Debt ($) Annual Income ($)  DTI Ratio(%)  \
# 0                 1    2,699,591          11,855,260          23.0
# 1                 2   10,533,816          10,023,835         105.0
# 2                 3   14,751,324          15,005,604          98.0
# 3                 4    4,388,501           4,294,936         102.0
# 4                 5    6,139,463          11,554,404          53.0
#
#   Approval status
# 0        Approved
# 1        Declined
# 2        Declined
# 3        Declined
# 4        Declined
#        Applicant number  DTI Ratio(%)
# count        100.000000    100.000000
# mean          50.500000     75.480000
# std           29.011492     43.482373
# min            1.000000      2.000000
# 25%           25.750000     41.500000
# 50%           50.500000     77.000000
# 75%           75.250000     98.250000
# max          100.000000    209.000000

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Eazlizy/loan-approval-rates/main/loan%20approval%20rates.csv'
Reporting = pd.read_csv(url)
Reporting.sum()
# Out:
# Applicant number                                                  5050
# Total Debt ($)       2,699,591  10,533,816  14,751,324  4,388,501  ...
# Annual Income ($)    11,855,26010,023,83515,005,6044,294,93611,554,...
# DTI Ratio(%)         23%105%98%102%53%179%7%73%192%209%100%100%115%...
# Approval status      ApprovedDeclinedDeclinedDeclinedDeclinedDeclin...
# dtype: object

# %%
Reporting[['DTI Ratio(%)','Approval status']].groupby('Approval status').sum()
# Out:
#                                                       DTI Ratio(%)
# Approval status
# Approved         23%7%42%33%18%25%28%37%22%40%4%17%28%22%28%21%...
# Declined         105%98%102%53%179%73%192%209%100%100%115%74%94...

# %%
top_5_dti_ratio = data.sort_values(by='DTI Ratio(%)', ascending=False).head(5)
print("DTI Ratio(%) with Highest Approval status:")
print(top_5_dti_ratio[['DTI Ratio(%)', 'Approval status']])
# Out:
# DTI Ratio(%) with Highest Approval status:
#    DTI Ratio(%) Approval status
# 61          99%        Declined
# 2           98%        Declined
# 50          97%        Declined
# 32          96%        Declined
# 20          95%        Declined

# %%
import matplotlib.pyplot as plt
top_5_dti_ratio = data.sort_values(by='DTI Ratio(%)', ascending=False).head(5)
plt.figure(figsize=(10, 6))
plt.bar(top_5_dti_ratio['DTI Ratio(%)'], top_5_dti_ratio.index, color='skyblue')
plt.xlabel('DTI Ratio(%)')
plt.ylabel('Applicant Number')
plt.title('Top 5 DTI Ratios with Highest Approval Status')
plt.gca().invert_yaxis()
plt.show()

# %%
import matplotlib.pyplot as plt
top_5_dti_ratio = data.sort_values(by='DTI Ratio(%)', ascending=False).head(5)
plt.figure(figsize=(10, 6))
plt.scatter(top_5_dti_ratio['DTI Ratio(%)'], top_5_dti_ratio.index, c='green', marker='o', label='Approval Status')
plt.xlabel('DTI Ratio(%)')
plt.ylabel('Applicant Number')
plt.title('Scatter Plot of Top 5 DTI Ratios vs. Approval Status')
plt.gca().invert_yaxis()
plt.legend()
plt.grid(True)
plt.show()
